# %%
# Write a python expression that takes a variable x and returns the following: 
"The variable x has a value of <the value of x>"

# %%
x = input()
print('the variable has the value of : ' + x)
# Out:
#  6
# the variable has the value of : 6

# %%
# What does the ls command do? What does the cd command do? What do they stand for?
ls: List, shows the files in the directory we're in
cd: Changes directory
